# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("World Energy Consumption.csv")

# %%
df.head()
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_elec_per_capita  \
# ...

# %%
df.shape
# Out:
# (17432, 122)

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia Pacific', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'CIS', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Central America',
#        'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Czechoslovakia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Eastern Africa', 'Ecuador', 'Egypt',
# ...

# %%
len_species=df["country"].unique()
print(len(len_species),"adet ülke var")
# Out:
# 242 adet ülke var

# %%
some_energies_consumption = ["nuclear_consumption","oil_consumption","fossil_fuel_consumption","solar_consumption","hydro_consumption","wind_consumption","gas_consumption"]
consumption_df=df[some_energies_consumption]
consumption_df.loc[(df['country'] == 'Canada') & (df['year'] == 2018)]
# Out:
#       nuclear_consumption  oil_consumption  fossil_fuel_consumption  \
# 3009              248.616         1274.945                 2638.454
#
#       solar_consumption  hydro_consumption  wind_consumption  gas_consumption
# 3009              9.579            959.056            82.481         1182.794

# %%
turkey_2018 = consumption_df.loc[(df['country'] == 'Turkey') & (df['year'] == 2018)]
total_energy_consumption = turkey_2018['nuclear_consumption'] + turkey_2018['oil_consumption'] + turkey_2018['solar_consumption']+turkey_2018["fossil_fuel_consumption"]+turkey_2018["hydro_consumption"]+turkey_2018["wind_consumption"]+turkey_2018["gas_consumption"]
print("Türkiye'nin 2018'deki toplam enerji tüketimi:", total_energy_consumption.sum())
x=round(total_energy_consumption.sum(),2)
print("yuvarlanmış hali",x)
# Out:
# Türkiye'nin 2018'deki toplam enerji tüketimi: 2747.3759999999997
# yuvarlanmış hali 2747.38

# %%
df_2019 = df[df['year'] == 2019]
df_2018 = df[df['year'] == 2018]
toplam_enerji_tuketimi_2018 = df_2018[some_energies_consumption].sum()
toplam_enerji_tuketimi_2019 = df_2019[some_energies_consumption].sum()

# %%
toplam_enerji_tuketimi_2019
# Out:
# nuclear_consumption         18562.112
# oil_consumption            160859.780
# fossil_fuel_consumption    317728.072
# solar_consumption            4287.110
# hydro_consumption           23643.783
# wind_consumption             9103.226
# gas_consumption            117877.402
# dtype: float64

# %%
plt.figure(figsize=(6,4))
toplam_enerji_tuketimi_2019.plot(kind='bar', color='skyblue')
plt.title('total energy consumption')
plt.xlabel('types of energy')
plt.ylabel('total consumption')
plt.xticks(rotation=45)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

axs[0].pie(toplam_enerji_tuketimi_2018, labels=toplam_enerji_tuketimi_2018.index, autopct='%1.1f%%', startangle=90)
axs[0].set_title('Energy consumption in 2018')

axs[1].pie(toplam_enerji_tuketimi_2019, labels=toplam_enerji_tuketimi_2019.index, autopct='%1.1f%%', startangle=90)
axs[1].set_title('Energy consumption in 2019')

plt.show()

# %%
for index, row in world.iterrows():
    country_name = row['name']
    country_2018 = consumption_df.loc[(df['country'] == country_name) & (df['year'] == 2019)]
    
    total_energy_consumption = country_2018['nuclear_consumption'] + country_2018['oil_consumption'] + country_2018['solar_consumption'] + country_2018["fossil_fuel_consumption"] + country_2018["hydro_consumption"] + country_2018["wind_consumption"] + country_2018["gas_consumption"]
    
    total = total_energy_consumption.sum()
    rounded_total = round(total, 2)
    
    print(f"{country_name}'nin 2018'deki toplam enerji tüketimi:", rounded_total)
# Out:
# Fiji'nin 2018'deki toplam enerji tüketimi: 0.0
# Tanzania'nin 2018'deki toplam enerji tüketimi: 0.0
# W. Sahara'nin 2018'deki toplam enerji tüketimi: 0.0
# Canada'nin 2018'deki toplam enerji tüketimi: 6351.37
# United States of America'nin 2018'deki toplam enerji tüketimi: 0.0
# Kazakhstan'nin 2018'deki toplam enerji tüketimi: 1230.89
# Uzbekistan'nin 2018'deki toplam enerji tüketimi: 954.64
# Papua New Guinea'nin 2018'deki toplam enerji tüketimi: 0.0
# Indonesia'nin 2018'deki toplam enerji tüketimi: 3745.73
# Argentina'nin 2018'deki toplam enerji tüketimi: 1741.86
# Chile'nin 2018'deki toplam enerji tüketimi: 711.02
# Dem. Rep. Congo'nin 2018'deki toplam enerji tüketimi: 0.0
# Somalia'nin 2018'deki toplam enerji tüketimi: 0.0
# Kenya'nin 2018'deki toplam enerji tüketimi: 0.0
# Sudan'nin 2018'deki toplam enerji tüketimi: 0.0
# Chad'nin 2018'deki toplam enerji tüketimi: 0.0
# Haiti'nin 2018'deki toplam enerji tüketimi: 0.0
# Dominican Rep.'nin 2018'deki toplam enerji tüketimi: 0.0
# ...

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# ... (diğer kodlarınız)

enerji_tuketimi_2019 = {}  

for index, row in world.iterrows():
    country_name = row['name']
    country_2019 = consumption_df.loc[(df['country'] == country_name) & (df['year'] == 2019)]
    
    total_energy_consumption = country_2019['nuclear_consumption'] + country_2019['oil_consumption'] + country_2019['solar_consumption'] + country_2019["fossil_fuel_consumption"] + country_2019["hydro_consumption"] + country_2019["wind_consumption"] + country_2019["gas_consumption"]
    
    total = total_energy_consumption.sum()
    enerji_tuketimi_2019[country_name] = round(total, 2)

# Şimdi bu verileri harita üzerinde gösterme işlemi yapılabilir,
# ancak bunun için GeoPandas ile coğrafi verilerle çalışmak gerekebilir.
# Haritalandırma işlemi için ek bir kod gerekebilir.

# Haritalandırma işlemi için bir örnek:
# Örnek olarak, dünya haritasını oluşturalım:
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Enerji tüketimi verilerini harita ile birleştirme
world['Total Energy Consumption 2019'] = world['name'].map(enerji_tuketimi_2019)

# Haritayı görselleştirme
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.plot(column='Total Energy Consumption 2019', ax=ax, legend=True,
           legend_kwds={'label': "2019 Enerji Tüketimi", 'orientation': "horizontal"})
plt.title('2019 Dünya Ülkelerinin Enerji Tüketimi')
plt.show()
